# %% [markdown]
# # Biblioteca Pandas Python

# %% [markdown]
# Prof. Tiago Dias
#
# [Linkedin](https://www.linkedin.com/in/diasctiago/) | [Github](https://github.com/diasctiago) | [Blog](https://www.dadosaocubo.com/)

# %% [markdown]
# ### Importanto Bibliotecas

# %%
# importando a biblioteca
import pandas as pd

# %% [markdown]
# ### Exemplo Python

# %%
# Lendo dados de um arquivo CSV
df = pd.read_csv('example.csv', delimiter=';')
df.head(3)
# Out:
#    cd_cliente nm_cliente                 ds_email
# 0          11      Maria    maria@dadosaocubo.com
# 1          12       João     joao@dadosaocubo.com
# 2          13    Mariana  mariana@dadosaocubo.com

# %%
# Lendo dados de um arquivo Excel
df = pd.read_excel('example.xlsx')
df.head(3)
# Out:
#    cd_cliente nm_cliente                 ds_email
# 0          11      Maria    maria@dadosaocubo.com
# 1          12       João     joao@dadosaocubo.com
# 2          13    Mariana  mariana@dadosaocubo.com

# %%
# Lendo dados de um banco de dados SQL
import sqlite3
con = sqlite3.connect('example.db')
df = pd.read_sql_query('SELECT * FROM clientes', con)
df.head(3)
# Out:
#    cd_cliente nm_cliente                 ds_email
# 0          11      Maria    maria@dadosaocubo.com
# 1          12       João     joao@dadosaocubo.com
# 2          13    Mariana  mariana@dadosaocubo.com

# %%
# Selecionando uma coluna
coluna = df['nm_cliente']
coluna
# Out:
# 0      Maria
# 1       João
# 2    Mariana
# 3    Juliana
# 4        Ana
# 5       José
# Name: nm_cliente, dtype: object

# %%
# Selecionando várias colunas
colunas = df[['cd_cliente','nm_cliente']]
colunas
# Out:
#    cd_cliente nm_cliente
# 0          11      Maria
# 1          12       João
# 2          13    Mariana
# 3          14    Juliana
# 4          15        Ana
# 5          17       José

# %%
# Filtrando linhas
filtrado = df[df['cd_cliente'] > 14]
filtrado
# Out:
#    cd_cliente nm_cliente             ds_email
# 4          15        Ana  ana@dadosaocubo.com
# 5          17       José   ze@dadosaocubo.com

# %%
# Ordenando os dados
ordenado = df.sort_values('cd_cliente',ascending=False)
ordenado
# Out:
#    cd_cliente nm_cliente                 ds_email
# 5          17       José       ze@dadosaocubo.com
# 4          15        Ana      ana@dadosaocubo.com
# 3          14    Juliana     juli@dadosaocubo.com
# 2          13    Mariana  mariana@dadosaocubo.com
# 1          12       João     joao@dadosaocubo.com
# 0          11      Maria    maria@dadosaocubo.com

# %%
# Aplicando uma função a uma coluna
df['cd_cliente_new'] = df['cd_cliente'].apply(lambda x: x+1000)
df
# Out:
#    cd_cliente nm_cliente                 ds_email  cd_cliente_new
# 0          11      Maria    maria@dadosaocubo.com            1011
# 1          12       João     joao@dadosaocubo.com            1012
# 2          13    Mariana  mariana@dadosaocubo.com            1013
# 3          14    Juliana     juli@dadosaocubo.com            1014
# 4          15        Ana      ana@dadosaocubo.com            1015
# 5          17       José       ze@dadosaocubo.com            1017

# %%
# Resumo estatístico dos dados
resumo = df.describe()
resumo
# Out:
#        cd_cliente  cd_cliente_new
# count    6.000000        6.000000
# mean    13.666667     1013.666667
# std      2.160247        2.160247
# min     11.000000     1011.000000
# 25%     12.250000     1012.250000
# 50%     13.500000     1013.500000
# 75%     14.750000     1014.750000
# max     17.000000     1017.000000

# %%
# Contando o número de ocorrências de um valor
contagem = df['nm_cliente'].value_counts()
contagem
# Out:
# Maria      1
# João       1
# Mariana    1
# Juliana    1
# Ana        1
# José       1
# Name: nm_cliente, dtype: int64

# %%
# Calculando a correlação entre colunas
correlacao = df.corr()
correlacao
# Out:
# <ipython-input-14-32fecdc3eed5>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacao = df.corr()
#                 cd_cliente  cd_cliente_new
# cd_cliente             1.0             1.0
# cd_cliente_new         1.0             1.0

# %%
# Agrupando dados
agrupado = df.groupby('cd_cliente').mean()
agrupado
# Out:
# <ipython-input-15-ea2e9faf70b5>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   agrupado = df.groupby('cd_cliente').mean()
#             cd_cliente_new
# cd_cliente
# 11                  1011.0
# 12                  1012.0
# 13                  1013.0
# 14                  1014.0
# 15                  1015.0
# 17                  1017.0

# %%
# Gráfico de barras
df.plot.bar(x='nm_cliente', y='cd_cliente');

# %%
# Gráfico de dispersão
df.plot.scatter(x='cd_cliente', y='cd_cliente_new');

# %%
# Gráfico de linha
df.plot.line(x='nm_cliente', y='cd_cliente')
# Out:
# <Axes: xlabel='nm_cliente'>
